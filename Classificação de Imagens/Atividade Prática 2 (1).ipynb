# %% [markdown]
# # Curso: Redes Neurais e Deep Learning
#
# Prof. Denilson Alves Pereira
# https://sites.google.com/ufla.br/denilsonpereira/
# Departamento de Ciência da Computação -
# Instituto de Ciências Exatas e Tecnológicas -
# Universidade Federal de Lavras
#
# # Atividade Prática 02
#
# **Instruções:**
# 1. Siga os passos indicados em cada célula abaixo para completar a atividade.
# 2. Você deve inserir código somente entre as linhas marcadas com **INICIE O CÓDIGO AQUI** e **TERMINE O CÓDIGO AQUI**. Há uma indicação de quantas linhas de código são necessárias.
# 3. Em alguns pontos, confira o resultado esperado conforme marcado com **SAÍDA ESPERADA**.
#
# **Tempo estimado para execução**: 1 hora
#
# Versão: Junho, 2021

# %% [markdown]
# ## O Problema a ser Resolvido
#
# O objetivo da atividade é elaborar uma rede neural para predizer se o animal de uma imagem é um gato ou um cachorro. <br>
#
# Será usado um dataset contendo 8.000 imagens para treinamento e 4.000 para teste, sendo a metade delas de gatos e a outra metade, de cachorros. As imagens têm tamanhos diversos e estão no formato RGB.
#
# Você vai praticar as seguintes habilidades:
# - Ler arquivos de imagens e convertê-los para vetores de pixels
# - Utilizar um gerador de dados aumentados para expandir o conjunto de imagens para treinamento da rede
# - Configurar uma rede neural simples para um problema de classificação multiclasse de imagens. Embora só existam duas classes, a saída será configurada para predizer "cat" se a imagem é de um gato ou "dog" se a imagem é de um cachorro.
#
# É importante destacar que a arquitetura de rede neural utilizada no nesta atividade **não** é a mais indicada para classificar imagens. Para uma melhor eficácia, devem ser adicionadas algumas camadas de Redes Neurais Convolucionais (CNN), que é assunto do próximo curso.

# %% [markdown]
# ## Pacotes

# %%
# !pip install --upgrade pip
# !pip install pandas
# !pip install matplotlib
# !pip install keras_preprocessing
# !pip install tensorflow
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: keras_preprocessing in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.26.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.16.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)

# %%
# Importando o dataset diretamente do Kaggle

# !kaggle datasets download -d d4rklucif3r/cat-and-dogs -p /content/
# !unzip -o /content/cat-and-dogs.zip -d /content/
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: /content/dataset/training_set/cats/cat.37.jpg
#   inflating: /content/dataset/training_set/cats/cat.370.jpg
#   inflating: /content/dataset/training_set/cats/cat.3700.jpg
#   inflating: /content/dataset/training_set/cats/cat.3701.jpg
#   inflating: /content/dataset/training_set/cats/cat.3702.jpg
#   inflating: /content/dataset/training_set/cats/cat.3703.jpg
#   inflating: /content/dataset/training_set/cats/cat.3704.jpg
#   inflating: /content/dataset/training_set/cats/cat.3705.jpg
#   inflating: /content/dataset/training_set/cats/cat.3706.jpg
#   inflating: /content/dataset/training_set/cats/cat.3707.jpg
#   inflating: /content/dataset/training_set/cats/cat.3708.jpg
#   inflating: /content/dataset/training_set/cats/cat.3709.jpg
#   inflating: /content/dataset/training_set/cats/cat.371.jpg
#   inflating: /content/dataset/training_set/cats/cat.3710.jpg
#   inflating: /content/dataset/training_set/cats/cat.3711.jpg
#   inflating: /content/dataset/training_set/cats/cat.3712.jpg
#   inflating: /content/dataset/training_set/cats/cat.3713.jpg
#   inflating: /content/dataset/training_set/cats/cat.3714.jpg
#   inflating: /content/dataset/training_set/cats/cat.3715.jpg
#   inflating: /content/dataset/training_set/cats/cat.3716.jpg
#   inflating: /content/dataset/training_set/cats/cat.3717.jpg
#   inflating: /content/dataset/training_set/cats/cat.3718.jpg
#   inflating: /content/dataset/training_set/cats/cat.3719.jpg
#   inflating: /content/dataset/training_set/cats/cat.372.jpg
#   inflating: /content/dataset/training_set/cats/cat.3720.jpg
#   inflating: /content/dataset/training_set/cats/cat.3721.jpg
#   inflating: /content/dataset/training_set/cats/cat.3722.jpg
#   inflating: /content/dataset/training_set/cats/cat.3723.jpg
#   inflating: /content/dataset/training_set/cats/cat.3724.jpg
#   inflating: /content/dataset/training_set/cats/cat.3725.jpg
#   inflating: /content/dataset/training_set/cats/cat.3726.jpg
#   inflating: /content/dataset/training_set/cats/cat.3727.jpg
#   inflating: /content/dataset/training_set/cats/cat.3728.jpg
#   inflating: /content/dataset/training_set/cats/cat.3729.jpg
#   inflating: /content/dataset/training_set/cats/cat.373.jpg
#   inflating: /content/dataset/training_set/cats/cat.3730.jpg
#   inflating: /content/dataset/training_set/cats/cat.3731.jpg
#   inflating: /content/dataset/training_set/cats/cat.3732.jpg
#   inflating: /content/dataset/training_set/cats/cat.3733.jpg
#   inflating: /content/dataset/training_set/cats/cat.3734.jpg
#   inflating: /content/dataset/training_set/cats/cat.3735.jpg
#   inflating: /content/dataset/training_set/cats/cat.3736.jpg
#   inflating: /content/dataset/training_set/cats/cat.3737.jpg
#   inflating: /content/dataset/training_set/cats/cat.3738.jpg
#   inflating: /content/dataset/training_set/cats/cat.3739.jpg
#   inflating: /content/dataset/training_set/cats/cat.374.jpg
#   inflating: /content/dataset/training_set/cats/cat.3740.jpg
#   inflating: /content/dataset/training_set/cats/cat.3741.jpg
#   inflating: /content/dataset/training_set/cats/cat.3742.jpg
#   inflating: /content/dataset/training_set/cats/cat.3743.jpg
#   inflating: /content/dataset/training_set/cats/cat.3744.jpg
#   inflating: /content/dataset/training_set/cats/cat.3745.jpg
#   inflating: /content/dataset/training_set/cats/cat.3746.jpg
#   inflating: /content/dataset/training_set/cats/cat.3747.jpg
#   inflating: /content/dataset/training_set/cats/cat.3748.jpg
#   inflating: /content/dataset/training_set/cats/cat.3749.jpg
#   inflating: /content/dataset/training_set/cats/cat.375.jpg
#   inflating: /content/dataset/training_set/cats/cat.3750.jpg
#   inflating: /content/dataset/training_set/cats/cat.3751.jpg
#   inflating: /content/dataset/training_set/cats/cat.3752.jpg
#   inflating: /content/dataset/training_set/cats/cat.3753.jpg
#   inflating: /content/dataset/training_set/cats/cat.3754.jpg
#   inflating: /content/dataset/training_set/cats/cat.3755.jpg
#   inflating: /content/dataset/training_set/cats/cat.3756.jpg
#   inflating: /content/dataset/training_set/cats/cat.3757.jpg
#   inflating: /content/dataset/training_set/cats/cat.3758.jpg
#   inflating: /content/dataset/training_set/cats/cat.3759.jpg
#   inflating: /content/dataset/training_set/cats/cat.376.jpg
#   inflating: /content/dataset/training_set/cats/cat.3760.jpg
#   inflating: /content/dataset/training_set/cats/cat.3761.jpg
#   inflating: /content/dataset/training_set/cats/cat.3762.jpg
#   inflating: /content/dataset/training_set/cats/cat.3763.jpg
#   inflating: /content/dataset/training_set/cats/cat.3764.jpg
#   inflating: /content/dataset/training_set/cats/cat.3765.jpg
#   inflating: /content/dataset/training_set/cats/cat.3766.jpg
#   inflating: /content/dataset/training_set/cats/cat.3767.jpg
#   inflating: /content/dataset/training_set/cats/cat.3768.jpg
#   inflating: /content/dataset/training_set/cats/cat.3769.jpg
#   inflating: /content/dataset/training_set/cats/cat.377.jpg
#   inflating: /content/dataset/training_set/cats/cat.3770.jpg
#   inflating: /content/dataset/training_set/cats/cat.3771.jpg
#   inflating: /content/dataset/training_set/cats/cat.3772.jpg
#   inflating: /content/dataset/training_set/cats/cat.3773.jpg
#   inflating: /content/dataset/training_set/cats/cat.3774.jpg
#   inflating: /content/dataset/training_set/cats/cat.3775.jpg
#   inflating: /content/dataset/training_set/cats/cat.3776.jpg
#   inflating: /content/dataset/training_set/cats/cat.3777.jpg
#   inflating: /content/dataset/training_set/cats/cat.3778.jpg
#   inflating: /content/dataset/training_set/cats/cat.3779.jpg
#   inflating: /content/dataset/training_set/cats/cat.378.jpg
#   inflating: /content/dataset/training_set/cats/cat.3780.jpg
#   inflating: /content/dataset/training_set/cats/cat.3781.jpg
#   inflating: /content/dataset/training_set/cats/cat.3782.jpg
#   inflating: /content/dataset/training_set/cats/cat.3783.jpg
#   inflating: /content/dataset/training_set/cats/cat.3784.jpg
#   inflating: /content/dataset/training_set/cats/cat.3785.jpg
#   inflating: /content/dataset/training_set/cats/cat.3786.jpg
#   inflating: /content/dataset/training_set/cats/cat.3787.jpg
#   inflating: /content/dataset/training_set/cats/cat.3788.jpg
#   inflating: /content/dataset/training_set/cats/cat.3789.jpg
#   inflating: /content/dataset/training_set/cats/cat.379.jpg
#   inflating: /content/dataset/training_set/cats/cat.3790.jpg
#   inflating: /content/dataset/training_set/cats/cat.3791.jpg
#   inflating: /content/dataset/training_set/cats/cat.3792.jpg
#   inflating: /content/dataset/training_set/cats/cat.3793.jpg
#   inflating: /content/dataset/training_set/cats/cat.3794.jpg
#   inflating: /content/dataset/training_set/cats/cat.3795.jpg
#   inflating: /content/dataset/training_set/cats/cat.3796.jpg
#   inflating: /content/dataset/training_set/cats/cat.3797.jpg
#   inflating: /content/dataset/training_set/cats/cat.3798.jpg
#   inflating: /content/dataset/training_set/cats/cat.3799.jpg
#   inflating: /content/dataset/training_set/cats/cat.38.jpg
#   inflating: /content/dataset/training_set/cats/cat.380.jpg
#   inflating: /content/dataset/training_set/cats/cat.3800.jpg
#   inflating: /content/dataset/training_set/cats/cat.3801.jpg
#   inflating: /content/dataset/training_set/cats/cat.3802.jpg
#   inflating: /content/dataset/training_set/cats/cat.3803.jpg
#   inflating: /content/dataset/training_set/cats/cat.3804.jpg
#   inflating: /content/dataset/training_set/cats/cat.3805.jpg
#   inflating: /content/dataset/training_set/cats/cat.3806.jpg
#   inflating: /content/dataset/training_set/cats/cat.3807.jpg
#   inflating: /content/dataset/training_set/cats/cat.3808.jpg
#   inflating: /content/dataset/training_set/cats/cat.3809.jpg
#   inflating: /content/dataset/training_set/cats/cat.381.jpg
#   inflating: /content/dataset/training_set/cats/cat.3810.jpg
#   inflating: /content/dataset/training_set/cats/cat.3811.jpg
#   inflating: /content/dataset/training_set/cats/cat.3812.jpg
#   inflating: /content/dataset/training_set/cats/cat.3813.jpg
#   inflating: /content/dataset/training_set/cats/cat.3814.jpg
#   inflating: /content/dataset/training_set/cats/cat.3815.jpg
#   inflating: /content/dataset/training_set/cats/cat.3816.jpg
#   inflating: /content/dataset/training_set/cats/cat.3817.jpg
#   inflating: /content/dataset/training_set/cats/cat.3818.jpg
#   inflating: /content/dataset/training_set/cats/cat.3819.jpg
#   inflating: /content/dataset/training_set/cats/cat.382.jpg
#   inflating: /content/dataset/training_set/cats/cat.3820.jpg
#   inflating: /content/dataset/training_set/cats/cat.3821.jpg
#   inflating: /content/dataset/training_set/cats/cat.3822.jpg
#   inflating: /content/dataset/training_set/cats/cat.3823.jpg
#   inflating: /content/dataset/training_set/cats/cat.3824.jpg
#   inflating: /content/dataset/training_set/cats/cat.3825.jpg
#   inflating: /content/dataset/training_set/cats/cat.3826.jpg
#   inflating: /content/dataset/training_set/cats/cat.3827.jpg
#   inflating: /content/dataset/training_set/cats/cat.3828.jpg
#   inflating: /content/dataset/training_set/cats/cat.3829.jpg
#   inflating: /content/dataset/training_set/cats/cat.383.jpg
#   inflating: /content/dataset/training_set/cats/cat.3830.jpg
#   inflating: /content/dataset/training_set/cats/cat.3831.jpg
#   inflating: /content/dataset/training_set/cats/cat.3832.jpg
#   inflating: /content/dataset/training_set/cats/cat.3833.jpg
#   inflating: /content/dataset/training_set/cats/cat.3834.jpg
#   inflating: /content/dataset/training_set/cats/cat.3835.jpg
#   inflating: /content/dataset/training_set/cats/cat.3836.jpg
#   inflating: /content/dataset/training_set/cats/cat.3837.jpg
#   inflating: /content/dataset/training_set/cats/cat.3838.jpg
#   inflating: /content/dataset/training_set/cats/cat.3839.jpg
#   inflating: /content/dataset/training_set/cats/cat.384.jpg
#   inflating: /content/dataset/training_set/cats/cat.3840.jpg
#   inflating: /content/dataset/training_set/cats/cat.3841.jpg
#   inflating: /content/dataset/training_set/cats/cat.3842.jpg
#   inflating: /content/dataset/training_set/cats/cat.3843.jpg
#   inflating: /content/dataset/training_set/cats/cat.3844.jpg
#   inflating: /content/dataset/training_set/cats/cat.3845.jpg
#   inflating: /content/dataset/training_set/cats/cat.3846.jpg
#   inflating: /content/dataset/training_set/cats/cat.3847.jpg
#   inflating: /content/dataset/training_set/cats/cat.3848.jpg
#   inflating: /content/dataset/training_set/cats/cat.3849.jpg
#   inflating: /content/dataset/training_set/cats/cat.385.jpg
#   inflating: /content/dataset/training_set/cats/cat.3850.jpg
#   inflating: /content/dataset/training_set/cats/cat.3851.jpg
#   inflating: /content/dataset/training_set/cats/cat.3852.jpg
#   inflating: /content/dataset/training_set/cats/cat.3853.jpg
#   inflating: /content/dataset/training_set/cats/cat.3854.jpg
#   inflating: /content/dataset/training_set/cats/cat.3855.jpg
#   inflating: /content/dataset/training_set/cats/cat.3856.jpg
#   inflating: /content/dataset/training_set/cats/cat.3857.jpg
#   inflating: /content/dataset/training_set/cats/cat.3858.jpg
#   inflating: /content/dataset/training_set/cats/cat.3859.jpg
#   inflating: /content/dataset/training_set/cats/cat.386.jpg
#   inflating: /content/dataset/training_set/cats/cat.3860.jpg
#   inflating: /content/dataset/training_set/cats/cat.3861.jpg
#   inflating: /content/dataset/training_set/cats/cat.3862.jpg
#   inflating: /content/dataset/training_set/cats/cat.3863.jpg
#   inflating: /content/dataset/training_set/cats/cat.3864.jpg
#   inflating: /content/dataset/training_set/cats/cat.3865.jpg
#   inflating: /content/dataset/training_set/cats/cat.3866.jpg
#   inflating: /content/dataset/training_set/cats/cat.3867.jpg
#   inflating: /content/dataset/training_set/cats/cat.3868.jpg
#   inflating: /content/dataset/training_set/cats/cat.3869.jpg
#   inflating: /content/dataset/training_set/cats/cat.387.jpg
#   inflating: /content/dataset/training_set/cats/cat.3870.jpg
#   inflating: /content/dataset/training_set/cats/cat.3871.jpg
#   inflating: /content/dataset/training_set/cats/cat.3872.jpg
#   inflating: /content/dataset/training_set/cats/cat.3873.jpg
#   inflating: /content/dataset/training_set/cats/cat.3874.jpg
#   inflating: /content/dataset/training_set/cats/cat.3875.jpg
#   inflating: /content/dataset/training_set/cats/cat.3876.jpg
#   inflating: /content/dataset/training_set/cats/cat.3877.jpg
#   inflating: /content/dataset/training_set/cats/cat.3878.jpg
#   inflating: /content/dataset/training_set/cats/cat.3879.jpg
#   inflating: /content/dataset/training_set/cats/cat.388.jpg
#   inflating: /content/dataset/training_set/cats/cat.3880.jpg
#   inflating: /content/dataset/training_set/cats/cat.3881.jpg
#   inflating: /content/dataset/training_set/cats/cat.3882.jpg
#   inflating: /content/dataset/training_set/cats/cat.3883.jpg
#   inflating: /content/dataset/training_set/cats/cat.3884.jpg
#   inflating: /content/dataset/training_set/cats/cat.3885.jpg
#   inflating: /content/dataset/training_set/cats/cat.3886.jpg
#   inflating: /content/dataset/training_set/cats/cat.3887.jpg
#   inflating: /content/dataset/training_set/cats/cat.3888.jpg
#   inflating: /content/dataset/training_set/cats/cat.3889.jpg
#   inflating: /content/dataset/training_set/cats/cat.389.jpg
#   inflating: /content/dataset/training_set/cats/cat.3890.jpg
#   inflating: /content/dataset/training_set/cats/cat.3891.jpg
#   inflating: /content/dataset/training_set/cats/cat.3892.jpg
#   inflating: /content/dataset/training_set/cats/cat.3893.jpg
#   inflating: /content/dataset/training_set/cats/cat.3894.jpg
#   inflating: /content/dataset/training_set/cats/cat.3895.jpg
#   inflating: /content/dataset/training_set/cats/cat.3896.jpg
#   inflating: /content/dataset/training_set/cats/cat.3897.jpg
#   inflating: /content/dataset/training_set/cats/cat.3898.jpg
#   inflating: /content/dataset/training_set/cats/cat.3899.jpg
#   inflating: /content/dataset/training_set/cats/cat.39.jpg
#   inflating: /content/dataset/training_set/cats/cat.390.jpg
#   inflating: /content/dataset/training_set/cats/cat.3900.jpg
#   inflating: /content/dataset/training_set/cats/cat.3901.jpg
#   inflating: /content/dataset/training_set/cats/cat.3902.jpg
#   inflating: /content/dataset/training_set/cats/cat.3903.jpg
#   inflating: /content/dataset/training_set/cats/cat.3904.jpg
#   inflating: /content/dataset/training_set/cats/cat.3905.jpg
#   inflating: /content/dataset/training_set/cats/cat.3906.jpg
#   inflating: /content/dataset/training_set/cats/cat.3907.jpg
#   inflating: /content/dataset/training_set/cats/cat.3908.jpg
#   inflating: /content/dataset/training_set/cats/cat.3909.jpg
#   inflating: /content/dataset/training_set/cats/cat.391.jpg
#   inflating: /content/dataset/training_set/cats/cat.3910.jpg
#   inflating: /content/dataset/training_set/cats/cat.3911.jpg
#   inflating: /content/dataset/training_set/cats/cat.3912.jpg
#   inflating: /content/dataset/training_set/cats/cat.3913.jpg
#   inflating: /content/dataset/training_set/cats/cat.3914.jpg
#   inflating: /content/dataset/training_set/cats/cat.3915.jpg
#   inflating: /content/dataset/training_set/cats/cat.3916.jpg
#   inflating: /content/dataset/training_set/cats/cat.3917.jpg
#   inflating: /content/dataset/training_set/cats/cat.3918.jpg
#   inflating: /content/dataset/training_set/cats/cat.3919.jpg
#   inflating: /content/dataset/training_set/cats/cat.392.jpg
#   inflating: /content/dataset/training_set/cats/cat.3920.jpg
#   inflating: /content/dataset/training_set/cats/cat.3921.jpg
#   inflating: /content/dataset/training_set/cats/cat.3922.jpg
#   inflating: /content/dataset/training_set/cats/cat.3923.jpg
#   inflating: /content/dataset/training_set/cats/cat.3924.jpg
#   inflating: /content/dataset/training_set/cats/cat.3925.jpg
#   inflating: /content/dataset/training_set/cats/cat.3926.jpg
#   inflating: /content/dataset/training_set/cats/cat.3927.jpg
#   inflating: /content/dataset/training_set/cats/cat.3928.jpg
#   inflating: /content/dataset/training_set/cats/cat.3929.jpg
#   inflating: /content/dataset/training_set/cats/cat.393.jpg
#   inflating: /content/dataset/training_set/cats/cat.3930.jpg
#   inflating: /content/dataset/training_set/cats/cat.3931.jpg
#   inflating: /content/dataset/training_set/cats/cat.3932.jpg
#   inflating: /content/dataset/training_set/cats/cat.3933.jpg
#   inflating: /content/dataset/training_set/cats/cat.3934.jpg
#   inflating: /content/dataset/training_set/cats/cat.3935.jpg
#   inflating: /content/dataset/training_set/cats/cat.3936.jpg
#   inflating: /content/dataset/training_set/cats/cat.3937.jpg
#   inflating: /content/dataset/training_set/cats/cat.3938.jpg
#   inflating: /content/dataset/training_set/cats/cat.3939.jpg
#   inflating: /content/dataset/training_set/cats/cat.394.jpg
#   inflating: /content/dataset/training_set/cats/cat.3940.jpg
#   inflating: /content/dataset/training_set/cats/cat.3941.jpg
#   inflating: /content/dataset/training_set/cats/cat.3942.jpg
#   inflating: /content/dataset/training_set/cats/cat.3943.jpg
#   inflating: /content/dataset/training_set/cats/cat.3944.jpg
#   inflating: /content/dataset/training_set/cats/cat.3945.jpg
#   inflating: /content/dataset/training_set/cats/cat.3946.jpg
#   inflating: /content/dataset/training_set/cats/cat.3947.jpg
#   inflating: /content/dataset/training_set/cats/cat.3948.jpg
#   inflating: /content/dataset/training_set/cats/cat.3949.jpg
#   inflating: /content/dataset/training_set/cats/cat.395.jpg
#   inflating: /content/dataset/training_set/cats/cat.3950.jpg
#   inflating: /content/dataset/training_set/cats/cat.3951.jpg
#   inflating: /content/dataset/training_set/cats/cat.3952.jpg
#   inflating: /content/dataset/training_set/cats/cat.3953.jpg
#   inflating: /content/dataset/training_set/cats/cat.3954.jpg
#   inflating: /content/dataset/training_set/cats/cat.3955.jpg
#   inflating: /content/dataset/training_set/cats/cat.3956.jpg
#   inflating: /content/dataset/training_set/cats/cat.3957.jpg
#   inflating: /content/dataset/training_set/cats/cat.3958.jpg
#   inflating: /content/dataset/training_set/cats/cat.3959.jpg
#   inflating: /content/dataset/training_set/cats/cat.396.jpg
#   inflating: /content/dataset/training_set/cats/cat.3960.jpg
#   inflating: /content/dataset/training_set/cats/cat.3961.jpg
#   inflating: /content/dataset/training_set/cats/cat.3962.jpg
#   inflating: /content/dataset/training_set/cats/cat.3963.jpg
#   inflating: /content/dataset/training_set/cats/cat.3964.jpg
#   inflating: /content/dataset/training_set/cats/cat.3965.jpg
#   inflating: /content/dataset/training_set/cats/cat.3966.jpg
#   inflating: /content/dataset/training_set/cats/cat.3967.jpg
#   inflating: /content/dataset/training_set/cats/cat.3968.jpg
#   inflating: /content/dataset/training_set/cats/cat.3969.jpg
#   inflating: /content/dataset/training_set/cats/cat.397.jpg
#   inflating: /content/dataset/training_set/cats/cat.3970.jpg
#   inflating: /content/dataset/training_set/cats/cat.3971.jpg
#   inflating: /content/dataset/training_set/cats/cat.3972.jpg
#   inflating: /content/dataset/training_set/cats/cat.3973.jpg
#   inflating: /content/dataset/training_set/cats/cat.3974.jpg
#   inflating: /content/dataset/training_set/cats/cat.3975.jpg
#   inflating: /content/dataset/training_set/cats/cat.3976.jpg
#   inflating: /content/dataset/training_set/cats/cat.3977.jpg
#   inflating: /content/dataset/training_set/cats/cat.3978.jpg
#   inflating: /content/dataset/training_set/cats/cat.3979.jpg
#   inflating: /content/dataset/training_set/cats/cat.398.jpg
#   inflating: /content/dataset/training_set/cats/cat.3980.jpg
#   inflating: /content/dataset/training_set/cats/cat.3981.jpg
#   inflating: /content/dataset/training_set/cats/cat.3982.jpg
#   inflating: /content/dataset/training_set/cats/cat.3983.jpg
#   inflating: /content/dataset/training_set/cats/cat.3984.jpg
#   inflating: /content/dataset/training_set/cats/cat.3985.jpg
#   inflating: /content/dataset/training_set/cats/cat.3986.jpg
#   inflating: /content/dataset/training_set/cats/cat.3987.jpg
#   inflating: /content/dataset/training_set/cats/cat.3988.jpg
#   inflating: /content/dataset/training_set/cats/cat.3989.jpg
#   inflating: /content/dataset/training_set/cats/cat.399.jpg
#   inflating: /content/dataset/training_set/cats/cat.3990.jpg
#   inflating: /content/dataset/training_set/cats/cat.3991.jpg
#   inflating: /content/dataset/training_set/cats/cat.3992.jpg
#   inflating: /content/dataset/training_set/cats/cat.3993.jpg
#   inflating: /content/dataset/training_set/cats/cat.3994.jpg
#   inflating: /content/dataset/training_set/cats/cat.3995.jpg
#   inflating: /content/dataset/training_set/cats/cat.3996.jpg
#   inflating: /content/dataset/training_set/cats/cat.3997.jpg
#   inflating: /content/dataset/training_set/cats/cat.3998.jpg
#   inflating: /content/dataset/training_set/cats/cat.3999.jpg
#   inflating: /content/dataset/training_set/cats/cat.4.jpg
#   inflating: /content/dataset/training_set/cats/cat.40.jpg
#   inflating: /content/dataset/training_set/cats/cat.400.jpg
#   inflating: /content/dataset/training_set/cats/cat.4000.jpg
#   inflating: /content/dataset/training_set/cats/cat.401.jpg
#   inflating: /content/dataset/training_set/cats/cat.402.jpg
#   inflating: /content/dataset/training_set/cats/cat.403.jpg
#   inflating: /content/dataset/training_set/cats/cat.404.jpg
#   inflating: /content/dataset/training_set/cats/cat.405.jpg
#   inflating: /content/dataset/training_set/cats/cat.406.jpg
#   inflating: /content/dataset/training_set/cats/cat.407.jpg
#   inflating: /content/dataset/training_set/cats/cat.408.jpg
#   inflating: /content/dataset/training_set/cats/cat.409.jpg
#   inflating: /content/dataset/training_set/cats/cat.41.jpg
#   inflating: /content/dataset/training_set/cats/cat.410.jpg
#   inflating: /content/dataset/training_set/cats/cat.411.jpg
#   inflating: /content/dataset/training_set/cats/cat.412.jpg
#   inflating: /content/dataset/training_set/cats/cat.413.jpg
#   inflating: /content/dataset/training_set/cats/cat.414.jpg
#   inflating: /content/dataset/training_set/cats/cat.415.jpg
#   inflating: /content/dataset/training_set/cats/cat.416.jpg
#   inflating: /content/dataset/training_set/cats/cat.417.jpg
#   inflating: /content/dataset/training_set/cats/cat.418.jpg
#   inflating: /content/dataset/training_set/cats/cat.419.jpg
#   inflating: /content/dataset/training_set/cats/cat.42.jpg
#   inflating: /content/dataset/training_set/cats/cat.420.jpg
#   inflating: /content/dataset/training_set/cats/cat.421.jpg
#   inflating: /content/dataset/training_set/cats/cat.422.jpg
#   inflating: /content/dataset/training_set/cats/cat.423.jpg
#   inflating: /content/dataset/training_set/cats/cat.424.jpg
#   inflating: /content/dataset/training_set/cats/cat.425.jpg
#   inflating: /content/dataset/training_set/cats/cat.426.jpg
#   inflating: /content/dataset/training_set/cats/cat.427.jpg
#   inflating: /content/dataset/training_set/cats/cat.428.jpg
#   inflating: /content/dataset/training_set/cats/cat.429.jpg
#   inflating: /content/dataset/training_set/cats/cat.43.jpg
#   inflating: /content/dataset/training_set/cats/cat.430.jpg
#   inflating: /content/dataset/training_set/cats/cat.431.jpg
#   inflating: /content/dataset/training_set/cats/cat.432.jpg
#   inflating: /content/dataset/training_set/cats/cat.433.jpg
#   inflating: /content/dataset/training_set/cats/cat.434.jpg
#   inflating: /content/dataset/training_set/cats/cat.435.jpg
#   inflating: /content/dataset/training_set/cats/cat.436.jpg
#   inflating: /content/dataset/training_set/cats/cat.437.jpg
#   inflating: /content/dataset/training_set/cats/cat.438.jpg
#   inflating: /content/dataset/training_set/cats/cat.439.jpg
#   inflating: /content/dataset/training_set/cats/cat.44.jpg
#   inflating: /content/dataset/training_set/cats/cat.440.jpg
#   inflating: /content/dataset/training_set/cats/cat.441.jpg
#   inflating: /content/dataset/training_set/cats/cat.442.jpg
#   inflating: /content/dataset/training_set/cats/cat.443.jpg
#   inflating: /content/dataset/training_set/cats/cat.444.jpg
#   inflating: /content/dataset/training_set/cats/cat.445.jpg
#   inflating: /content/dataset/training_set/cats/cat.446.jpg
#   inflating: /content/dataset/training_set/cats/cat.447.jpg
#   inflating: /content/dataset/training_set/cats/cat.448.jpg
#   inflating: /content/dataset/training_set/cats/cat.449.jpg
#   inflating: /content/dataset/training_set/cats/cat.45.jpg
#   inflating: /content/dataset/training_set/cats/cat.450.jpg
#   inflating: /content/dataset/training_set/cats/cat.451.jpg
#   inflating: /content/dataset/training_set/cats/cat.452.jpg
#   inflating: /content/dataset/training_set/cats/cat.453.jpg
#   inflating: /content/dataset/training_set/cats/cat.454.jpg
#   inflating: /content/dataset/training_set/cats/cat.455.jpg
#   inflating: /content/dataset/training_set/cats/cat.456.jpg
#   inflating: /content/dataset/training_set/cats/cat.457.jpg
#   inflating: /content/dataset/training_set/cats/cat.458.jpg
#   inflating: /content/dataset/training_set/cats/cat.459.jpg
#   inflating: /content/dataset/training_set/cats/cat.46.jpg
#   inflating: /content/dataset/training_set/cats/cat.460.jpg
#   inflating: /content/dataset/training_set/cats/cat.461.jpg
#   inflating: /content/dataset/training_set/cats/cat.462.jpg
#   inflating: /content/dataset/training_set/cats/cat.463.jpg
#   inflating: /content/dataset/training_set/cats/cat.464.jpg
#   inflating: /content/dataset/training_set/cats/cat.465.jpg
#   inflating: /content/dataset/training_set/cats/cat.466.jpg
#   inflating: /content/dataset/training_set/cats/cat.467.jpg
#   inflating: /content/dataset/training_set/cats/cat.468.jpg
#   inflating: /content/dataset/training_set/cats/cat.469.jpg
#   inflating: /content/dataset/training_set/cats/cat.47.jpg
#   inflating: /content/dataset/training_set/cats/cat.470.jpg
#   inflating: /content/dataset/training_set/cats/cat.471.jpg
#   inflating: /content/dataset/training_set/cats/cat.472.jpg
#   inflating: /content/dataset/training_set/cats/cat.473.jpg
#   inflating: /content/dataset/training_set/cats/cat.474.jpg
#   inflating: /content/dataset/training_set/cats/cat.475.jpg
#   inflating: /content/dataset/training_set/cats/cat.476.jpg
#   inflating: /content/dataset/training_set/cats/cat.477.jpg
#   inflating: /content/dataset/training_set/cats/cat.478.jpg
#   inflating: /content/dataset/training_set/cats/cat.479.jpg
#   inflating: /content/dataset/training_set/cats/cat.48.jpg
#   inflating: /content/dataset/training_set/cats/cat.480.jpg
#   inflating: /content/dataset/training_set/cats/cat.481.jpg
#   inflating: /content/dataset/training_set/cats/cat.482.jpg
#   inflating: /content/dataset/training_set/cats/cat.483.jpg
#   inflating: /content/dataset/training_set/cats/cat.484.jpg
#   inflating: /content/dataset/training_set/cats/cat.485.jpg
#   inflating: /content/dataset/training_set/cats/cat.486.jpg
#   inflating: /content/dataset/training_set/cats/cat.487.jpg
#   inflating: /content/dataset/training_set/cats/cat.488.jpg
#   inflating: /content/dataset/training_set/cats/cat.489.jpg
#   inflating: /content/dataset/training_set/cats/cat.49.jpg
#   inflating: /content/dataset/training_set/cats/cat.490.jpg
#   inflating: /content/dataset/training_set/cats/cat.491.jpg
#   inflating: /content/dataset/training_set/cats/cat.492.jpg
#   inflating: /content/dataset/training_set/cats/cat.493.jpg
#   inflating: /content/dataset/training_set/cats/cat.494.jpg
#   inflating: /content/dataset/training_set/cats/cat.495.jpg
#   inflating: /content/dataset/training_set/cats/cat.496.jpg
#   inflating: /content/dataset/training_set/cats/cat.497.jpg
#   inflating: /content/dataset/training_set/cats/cat.498.jpg
#   inflating: /content/dataset/training_set/cats/cat.499.jpg
#   inflating: /content/dataset/training_set/cats/cat.5.jpg
#   inflating: /content/dataset/training_set/cats/cat.50.jpg
#   inflating: /content/dataset/training_set/cats/cat.500.jpg
#   inflating: /content/dataset/training_set/cats/cat.501.jpg
#   inflating: /content/dataset/training_set/cats/cat.502.jpg
#   inflating: /content/dataset/training_set/cats/cat.503.jpg
#   inflating: /content/dataset/training_set/cats/cat.504.jpg
#   inflating: /content/dataset/training_set/cats/cat.505.jpg
#   inflating: /content/dataset/training_set/cats/cat.506.jpg
#   inflating: /content/dataset/training_set/cats/cat.507.jpg
#   inflating: /content/dataset/training_set/cats/cat.508.jpg
#   inflating: /content/dataset/training_set/cats/cat.509.jpg
#   inflating: /content/dataset/training_set/cats/cat.51.jpg
#   inflating: /content/dataset/training_set/cats/cat.510.jpg
#   inflating: /content/dataset/training_set/cats/cat.511.jpg
#   inflating: /content/dataset/training_set/cats/cat.512.jpg
#   inflating: /content/dataset/training_set/cats/cat.513.jpg
#   inflating: /content/dataset/training_set/cats/cat.514.jpg
#   inflating: /content/dataset/training_set/cats/cat.515.jpg
#   inflating: /content/dataset/training_set/cats/cat.516.jpg
#   inflating: /content/dataset/training_set/cats/cat.517.jpg
#   inflating: /content/dataset/training_set/cats/cat.518.jpg
#   inflating: /content/dataset/training_set/cats/cat.519.jpg
#   inflating: /content/dataset/training_set/cats/cat.52.jpg
#   inflating: /content/dataset/training_set/cats/cat.520.jpg
#   inflating: /content/dataset/training_set/cats/cat.521.jpg
#   inflating: /content/dataset/training_set/cats/cat.522.jpg
#   inflating: /content/dataset/training_set/cats/cat.523.jpg
#   inflating: /content/dataset/training_set/cats/cat.524.jpg
#   inflating: /content/dataset/training_set/cats/cat.525.jpg
#   inflating: /content/dataset/training_set/cats/cat.526.jpg
#   inflating: /content/dataset/training_set/cats/cat.527.jpg
#   inflating: /content/dataset/training_set/cats/cat.528.jpg
#   inflating: /content/dataset/training_set/cats/cat.529.jpg
#   inflating: /content/dataset/training_set/cats/cat.53.jpg
#   inflating: /content/dataset/training_set/cats/cat.530.jpg
#   inflating: /content/dataset/training_set/cats/cat.531.jpg
#   inflating: /content/dataset/training_set/cats/cat.532.jpg
#   inflating: /content/dataset/training_set/cats/cat.533.jpg
#   inflating: /content/dataset/training_set/cats/cat.534.jpg
#   inflating: /content/dataset/training_set/cats/cat.535.jpg
#   inflating: /content/dataset/training_set/cats/cat.536.jpg
#   inflating: /content/dataset/training_set/cats/cat.537.jpg
#   inflating: /content/dataset/training_set/cats/cat.538.jpg
#   inflating: /content/dataset/training_set/cats/cat.539.jpg
#   inflating: /content/dataset/training_set/cats/cat.54.jpg
#   inflating: /content/dataset/training_set/cats/cat.540.jpg
#   inflating: /content/dataset/training_set/cats/cat.541.jpg
#   inflating: /content/dataset/training_set/cats/cat.542.jpg
#   inflating: /content/dataset/training_set/cats/cat.543.jpg
#   inflating: /content/dataset/training_set/cats/cat.544.jpg
#   inflating: /content/dataset/training_set/cats/cat.545.jpg
#   inflating: /content/dataset/training_set/cats/cat.546.jpg
#   inflating: /content/dataset/training_set/cats/cat.547.jpg
#   inflating: /content/dataset/training_set/cats/cat.548.jpg
#   inflating: /content/dataset/training_set/cats/cat.549.jpg
#   inflating: /content/dataset/training_set/cats/cat.55.jpg
#   inflating: /content/dataset/training_set/cats/cat.550.jpg
#   inflating: /content/dataset/training_set/cats/cat.551.jpg
#   inflating: /content/dataset/training_set/cats/cat.552.jpg
#   inflating: /content/dataset/training_set/cats/cat.553.jpg
#   inflating: /content/dataset/training_set/cats/cat.554.jpg
#   inflating: /content/dataset/training_set/cats/cat.555.jpg
#   inflating: /content/dataset/training_set/cats/cat.556.jpg
#   inflating: /content/dataset/training_set/cats/cat.557.jpg
#   inflating: /content/dataset/training_set/cats/cat.558.jpg
#   inflating: /content/dataset/training_set/cats/cat.559.jpg
#   inflating: /content/dataset/training_set/cats/cat.56.jpg
#   inflating: /content/dataset/training_set/cats/cat.560.jpg
#   inflating: /content/dataset/training_set/cats/cat.561.jpg
#   inflating: /content/dataset/training_set/cats/cat.562.jpg
#   inflating: /content/dataset/training_set/cats/cat.563.jpg
#   inflating: /content/dataset/training_set/cats/cat.564.jpg
#   inflating: /content/dataset/training_set/cats/cat.565.jpg
#   inflating: /content/dataset/training_set/cats/cat.566.jpg
#   inflating: /content/dataset/training_set/cats/cat.567.jpg
#   inflating: /content/dataset/training_set/cats/cat.568.jpg
#   inflating: /content/dataset/training_set/cats/cat.569.jpg
#   inflating: /content/dataset/training_set/cats/cat.57.jpg
#   inflating: /content/dataset/training_set/cats/cat.570.jpg
#   inflating: /content/dataset/training_set/cats/cat.571.jpg
#   inflating: /content/dataset/training_set/cats/cat.572.jpg
#   inflating: /content/dataset/training_set/cats/cat.573.jpg
#   inflating: /content/dataset/training_set/cats/cat.574.jpg
#   inflating: /content/dataset/training_set/cats/cat.575.jpg
#   inflating: /content/dataset/training_set/cats/cat.576.jpg
#   inflating: /content/dataset/training_set/cats/cat.577.jpg
#   inflating: /content/dataset/training_set/cats/cat.578.jpg
#   inflating: /content/dataset/training_set/cats/cat.579.jpg
#   inflating: /content/dataset/training_set/cats/cat.58.jpg
#   inflating: /content/dataset/training_set/cats/cat.580.jpg
#   inflating: /content/dataset/training_set/cats/cat.581.jpg
#   inflating: /content/dataset/training_set/cats/cat.582.jpg
#   inflating: /content/dataset/training_set/cats/cat.583.jpg
#   inflating: /content/dataset/training_set/cats/cat.584.jpg
#   inflating: /content/dataset/training_set/cats/cat.585.jpg
#   inflating: /content/dataset/training_set/cats/cat.586.jpg
#   inflating: /content/dataset/training_set/cats/cat.587.jpg
#   inflating: /content/dataset/training_set/cats/cat.588.jpg
#   inflating: /content/dataset/training_set/cats/cat.589.jpg
#   inflating: /content/dataset/training_set/cats/cat.59.jpg
#   inflating: /content/dataset/training_set/cats/cat.590.jpg
#   inflating: /content/dataset/training_set/cats/cat.591.jpg
#   inflating: /content/dataset/training_set/cats/cat.592.jpg
#   inflating: /content/dataset/training_set/cats/cat.593.jpg
#   inflating: /content/dataset/training_set/cats/cat.594.jpg
#   inflating: /content/dataset/training_set/cats/cat.595.jpg
#   inflating: /content/dataset/training_set/cats/cat.596.jpg
#   inflating: /content/dataset/training_set/cats/cat.597.jpg
#   inflating: /content/dataset/training_set/cats/cat.598.jpg
#   inflating: /content/dataset/training_set/cats/cat.599.jpg
#   inflating: /content/dataset/training_set/cats/cat.6.jpg
#   inflating: /content/dataset/training_set/cats/cat.60.jpg
#   inflating: /content/dataset/training_set/cats/cat.600.jpg
#   inflating: /content/dataset/training_set/cats/cat.601.jpg
#   inflating: /content/dataset/training_set/cats/cat.602.jpg
#   inflating: /content/dataset/training_set/cats/cat.603.jpg
#   inflating: /content/dataset/training_set/cats/cat.604.jpg
#   inflating: /content/dataset/training_set/cats/cat.605.jpg
#   inflating: /content/dataset/training_set/cats/cat.606.jpg
#   inflating: /content/dataset/training_set/cats/cat.607.jpg
#   inflating: /content/dataset/training_set/cats/cat.608.jpg
#   inflating: /content/dataset/training_set/cats/cat.609.jpg
#   inflating: /content/dataset/training_set/cats/cat.61.jpg
#   inflating: /content/dataset/training_set/cats/cat.610.jpg
#   inflating: /content/dataset/training_set/cats/cat.611.jpg
#   inflating: /content/dataset/training_set/cats/cat.612.jpg
#   inflating: /content/dataset/training_set/cats/cat.613.jpg
#   inflating: /content/dataset/training_set/cats/cat.614.jpg
#   inflating: /content/dataset/training_set/cats/cat.615.jpg
#   inflating: /content/dataset/training_set/cats/cat.616.jpg
#   inflating: /content/dataset/training_set/cats/cat.617.jpg
#   inflating: /content/dataset/training_set/cats/cat.618.jpg
#   inflating: /content/dataset/training_set/cats/cat.619.jpg
#   inflating: /content/dataset/training_set/cats/cat.62.jpg
#   inflating: /content/dataset/training_set/cats/cat.620.jpg
#   inflating: /content/dataset/training_set/cats/cat.621.jpg
#   inflating: /content/dataset/training_set/cats/cat.622.jpg
#   inflating: /content/dataset/training_set/cats/cat.623.jpg
#   inflating: /content/dataset/training_set/cats/cat.624.jpg
#   inflating: /content/dataset/training_set/cats/cat.625.jpg
#   inflating: /content/dataset/training_set/cats/cat.626.jpg
#   inflating: /content/dataset/training_set/cats/cat.627.jpg
#   inflating: /content/dataset/training_set/cats/cat.628.jpg
#   inflating: /content/dataset/training_set/cats/cat.629.jpg
#   inflating: /content/dataset/training_set/cats/cat.63.jpg
#   inflating: /content/dataset/training_set/cats/cat.630.jpg
#   inflating: /content/dataset/training_set/cats/cat.631.jpg
#   inflating: /content/dataset/training_set/cats/cat.632.jpg
#   inflating: /content/dataset/training_set/cats/cat.633.jpg
#   inflating: /content/dataset/training_set/cats/cat.634.jpg
#   inflating: /content/dataset/training_set/cats/cat.635.jpg
#   inflating: /content/dataset/training_set/cats/cat.636.jpg
#   inflating: /content/dataset/training_set/cats/cat.637.jpg
#   inflating: /content/dataset/training_set/cats/cat.638.jpg
#   inflating: /content/dataset/training_set/cats/cat.639.jpg
#   inflating: /content/dataset/training_set/cats/cat.64.jpg
#   inflating: /content/dataset/training_set/cats/cat.640.jpg
#   inflating: /content/dataset/training_set/cats/cat.641.jpg
#   inflating: /content/dataset/training_set/cats/cat.642.jpg
#   inflating: /content/dataset/training_set/cats/cat.643.jpg
#   inflating: /content/dataset/training_set/cats/cat.644.jpg
#   inflating: /content/dataset/training_set/cats/cat.645.jpg
#   inflating: /content/dataset/training_set/cats/cat.646.jpg
#   inflating: /content/dataset/training_set/cats/cat.647.jpg
#   inflating: /content/dataset/training_set/cats/cat.648.jpg
#   inflating: /content/dataset/training_set/cats/cat.649.jpg
#   inflating: /content/dataset/training_set/cats/cat.65.jpg
#   inflating: /content/dataset/training_set/cats/cat.650.jpg
#   inflating: /content/dataset/training_set/cats/cat.651.jpg
#   inflating: /content/dataset/training_set/cats/cat.652.jpg
#   inflating: /content/dataset/training_set/cats/cat.653.jpg
#   inflating: /content/dataset/training_set/cats/cat.654.jpg
#   inflating: /content/dataset/training_set/cats/cat.655.jpg
#   inflating: /content/dataset/training_set/cats/cat.656.jpg
#   inflating: /content/dataset/training_set/cats/cat.657.jpg
#   inflating: /content/dataset/training_set/cats/cat.658.jpg
#   inflating: /content/dataset/training_set/cats/cat.659.jpg
#   inflating: /content/dataset/training_set/cats/cat.66.jpg
#   inflating: /content/dataset/training_set/cats/cat.660.jpg
#   inflating: /content/dataset/training_set/cats/cat.661.jpg
#   inflating: /content/dataset/training_set/cats/cat.662.jpg
#   inflating: /content/dataset/training_set/cats/cat.663.jpg
#   inflating: /content/dataset/training_set/cats/cat.664.jpg
#   inflating: /content/dataset/training_set/cats/cat.665.jpg
#   inflating: /content/dataset/training_set/cats/cat.666.jpg
#   inflating: /content/dataset/training_set/cats/cat.667.jpg
#   inflating: /content/dataset/training_set/cats/cat.668.jpg
#   inflating: /content/dataset/training_set/cats/cat.669.jpg
#   inflating: /content/dataset/training_set/cats/cat.67.jpg
#   inflating: /content/dataset/training_set/cats/cat.670.jpg
#   inflating: /content/dataset/training_set/cats/cat.671.jpg
#   inflating: /content/dataset/training_set/cats/cat.672.jpg
#   inflating: /content/dataset/training_set/cats/cat.673.jpg
#   inflating: /content/dataset/training_set/cats/cat.674.jpg
#   inflating: /content/dataset/training_set/cats/cat.675.jpg
#   inflating: /content/dataset/training_set/cats/cat.676.jpg
#   inflating: /content/dataset/training_set/cats/cat.677.jpg
#   inflating: /content/dataset/training_set/cats/cat.678.jpg
#   inflating: /content/dataset/training_set/cats/cat.679.jpg
#   inflating: /content/dataset/training_set/cats/cat.68.jpg
#   inflating: /content/dataset/training_set/cats/cat.680.jpg
#   inflating: /content/dataset/training_set/cats/cat.681.jpg
#   inflating: /content/dataset/training_set/cats/cat.682.jpg
#   inflating: /content/dataset/training_set/cats/cat.683.jpg
#   inflating: /content/dataset/training_set/cats/cat.684.jpg
#   inflating: /content/dataset/training_set/cats/cat.685.jpg
#   inflating: /content/dataset/training_set/cats/cat.686.jpg
#   inflating: /content/dataset/training_set/cats/cat.687.jpg
#   inflating: /content/dataset/training_set/cats/cat.688.jpg
#   inflating: /content/dataset/training_set/cats/cat.689.jpg
#   inflating: /content/dataset/training_set/cats/cat.69.jpg
#   inflating: /content/dataset/training_set/cats/cat.690.jpg
#   inflating: /content/dataset/training_set/cats/cat.691.jpg
#   inflating: /content/dataset/training_set/cats/cat.692.jpg
#   inflating: /content/dataset/training_set/cats/cat.693.jpg
#   inflating: /content/dataset/training_set/cats/cat.694.jpg
#   inflating: /content/dataset/training_set/cats/cat.695.jpg
#   inflating: /content/dataset/training_set/cats/cat.696.jpg
#   inflating: /content/dataset/training_set/cats/cat.697.jpg
#   inflating: /content/dataset/training_set/cats/cat.698.jpg
#   inflating: /content/dataset/training_set/cats/cat.699.jpg
#   inflating: /content/dataset/training_set/cats/cat.7.jpg
#   inflating: /content/dataset/training_set/cats/cat.70.jpg
#   inflating: /content/dataset/training_set/cats/cat.700.jpg
#   inflating: /content/dataset/training_set/cats/cat.701.jpg
#   inflating: /content/dataset/training_set/cats/cat.702.jpg
#   inflating: /content/dataset/training_set/cats/cat.703.jpg
#   inflating: /content/dataset/training_set/cats/cat.704.jpg
#   inflating: /content/dataset/training_set/cats/cat.705.jpg
#   inflating: /content/dataset/training_set/cats/cat.706.jpg
#   inflating: /content/dataset/training_set/cats/cat.707.jpg
#   inflating: /content/dataset/training_set/cats/cat.708.jpg
#   inflating: /content/dataset/training_set/cats/cat.709.jpg
#   inflating: /content/dataset/training_set/cats/cat.71.jpg
#   inflating: /content/dataset/training_set/cats/cat.710.jpg
#   inflating: /content/dataset/training_set/cats/cat.711.jpg
#   inflating: /content/dataset/training_set/cats/cat.712.jpg
#   inflating: /content/dataset/training_set/cats/cat.713.jpg
#   inflating: /content/dataset/training_set/cats/cat.714.jpg
#   inflating: /content/dataset/training_set/cats/cat.715.jpg
#   inflating: /content/dataset/training_set/cats/cat.716.jpg
#   inflating: /content/dataset/training_set/cats/cat.717.jpg
#   inflating: /content/dataset/training_set/cats/cat.718.jpg
#   inflating: /content/dataset/training_set/cats/cat.719.jpg
#   inflating: /content/dataset/training_set/cats/cat.72.jpg
#   inflating: /content/dataset/training_set/cats/cat.720.jpg
#   inflating: /content/dataset/training_set/cats/cat.721.jpg
#   inflating: /content/dataset/training_set/cats/cat.722.jpg
#   inflating: /content/dataset/training_set/cats/cat.723.jpg
#   inflating: /content/dataset/training_set/cats/cat.724.jpg
#   inflating: /content/dataset/training_set/cats/cat.725.jpg
#   inflating: /content/dataset/training_set/cats/cat.726.jpg
#   inflating: /content/dataset/training_set/cats/cat.727.jpg
#   inflating: /content/dataset/training_set/cats/cat.728.jpg
#   inflating: /content/dataset/training_set/cats/cat.729.jpg
#   inflating: /content/dataset/training_set/cats/cat.73.jpg
#   inflating: /content/dataset/training_set/cats/cat.730.jpg
#   inflating: /content/dataset/training_set/cats/cat.731.jpg
#   inflating: /content/dataset/training_set/cats/cat.732.jpg
#   inflating: /content/dataset/training_set/cats/cat.733.jpg
#   inflating: /content/dataset/training_set/cats/cat.734.jpg
#   inflating: /content/dataset/training_set/cats/cat.735.jpg
#   inflating: /content/dataset/training_set/cats/cat.736.jpg
#   inflating: /content/dataset/training_set/cats/cat.737.jpg
#   inflating: /content/dataset/training_set/cats/cat.738.jpg
#   inflating: /content/dataset/training_set/cats/cat.739.jpg
#   inflating: /content/dataset/training_set/cats/cat.74.jpg
#   inflating: /content/dataset/training_set/cats/cat.740.jpg
#   inflating: /content/dataset/training_set/cats/cat.741.jpg
#   inflating: /content/dataset/training_set/cats/cat.742.jpg
#   inflating: /content/dataset/training_set/cats/cat.743.jpg
#   inflating: /content/dataset/training_set/cats/cat.744.jpg
#   inflating: /content/dataset/training_set/cats/cat.745.jpg
#   inflating: /content/dataset/training_set/cats/cat.746.jpg
#   inflating: /content/dataset/training_set/cats/cat.747.jpg
#   inflating: /content/dataset/training_set/cats/cat.748.jpg
#   inflating: /content/dataset/training_set/cats/cat.749.jpg
#   inflating: /content/dataset/training_set/cats/cat.75.jpg
#   inflating: /content/dataset/training_set/cats/cat.750.jpg
#   inflating: /content/dataset/training_set/cats/cat.751.jpg
#   inflating: /content/dataset/training_set/cats/cat.752.jpg
#   inflating: /content/dataset/training_set/cats/cat.753.jpg
#   inflating: /content/dataset/training_set/cats/cat.754.jpg
#   inflating: /content/dataset/training_set/cats/cat.755.jpg
#   inflating: /content/dataset/training_set/cats/cat.756.jpg
#   inflating: /content/dataset/training_set/cats/cat.757.jpg
#   inflating: /content/dataset/training_set/cats/cat.758.jpg
#   inflating: /content/dataset/training_set/cats/cat.759.jpg
#   inflating: /content/dataset/training_set/cats/cat.76.jpg
#   inflating: /content/dataset/training_set/cats/cat.760.jpg
#   inflating: /content/dataset/training_set/cats/cat.761.jpg
#   inflating: /content/dataset/training_set/cats/cat.762.jpg
#   inflating: /content/dataset/training_set/cats/cat.763.jpg
#   inflating: /content/dataset/training_set/cats/cat.764.jpg
#   inflating: /content/dataset/training_set/cats/cat.765.jpg
#   inflating: /content/dataset/training_set/cats/cat.766.jpg
#   inflating: /content/dataset/training_set/cats/cat.767.jpg
#   inflating: /content/dataset/training_set/cats/cat.768.jpg
#   inflating: /content/dataset/training_set/cats/cat.769.jpg
#   inflating: /content/dataset/training_set/cats/cat.77.jpg
#   inflating: /content/dataset/training_set/cats/cat.770.jpg
#   inflating: /content/dataset/training_set/cats/cat.771.jpg
#   inflating: /content/dataset/training_set/cats/cat.772.jpg
#   inflating: /content/dataset/training_set/cats/cat.773.jpg
#   inflating: /content/dataset/training_set/cats/cat.774.jpg
#   inflating: /content/dataset/training_set/cats/cat.775.jpg
#   inflating: /content/dataset/training_set/cats/cat.776.jpg
#   inflating: /content/dataset/training_set/cats/cat.777.jpg
#   inflating: /content/dataset/training_set/cats/cat.778.jpg
#   inflating: /content/dataset/training_set/cats/cat.779.jpg
#   inflating: /content/dataset/training_set/cats/cat.78.jpg
#   inflating: /content/dataset/training_set/cats/cat.780.jpg
#   inflating: /content/dataset/training_set/cats/cat.781.jpg
#   inflating: /content/dataset/training_set/cats/cat.782.jpg
#   inflating: /content/dataset/training_set/cats/cat.783.jpg
#   inflating: /content/dataset/training_set/cats/cat.784.jpg
#   inflating: /content/dataset/training_set/cats/cat.785.jpg
#   inflating: /content/dataset/training_set/cats/cat.786.jpg
#   inflating: /content/dataset/training_set/cats/cat.787.jpg
#   inflating: /content/dataset/training_set/cats/cat.788.jpg
#   inflating: /content/dataset/training_set/cats/cat.789.jpg
#   inflating: /content/dataset/training_set/cats/cat.79.jpg
#   inflating: /content/dataset/training_set/cats/cat.790.jpg
# ...
#   inflating: /content/dataset/training_set/dogs/dog.767.jpg
#   inflating: /content/dataset/training_set/dogs/dog.768.jpg
#   inflating: /content/dataset/training_set/dogs/dog.769.jpg
#   inflating: /content/dataset/training_set/dogs/dog.77.jpg
#   inflating: /content/dataset/training_set/dogs/dog.770.jpg
#   inflating: /content/dataset/training_set/dogs/dog.771.jpg
#   inflating: /content/dataset/training_set/dogs/dog.772.jpg
#   inflating: /content/dataset/training_set/dogs/dog.773.jpg
#   inflating: /content/dataset/training_set/dogs/dog.774.jpg
#   inflating: /content/dataset/training_set/dogs/dog.775.jpg
#   inflating: /content/dataset/training_set/dogs/dog.776.jpg
#   inflating: /content/dataset/training_set/dogs/dog.777.jpg
#   inflating: /content/dataset/training_set/dogs/dog.778.jpg
#   inflating: /content/dataset/training_set/dogs/dog.779.jpg
#   inflating: /content/dataset/training_set/dogs/dog.78.jpg
#   inflating: /content/dataset/training_set/dogs/dog.780.jpg
#   inflating: /content/dataset/training_set/dogs/dog.781.jpg
#   inflating: /content/dataset/training_set/dogs/dog.782.jpg
#   inflating: /content/dataset/training_set/dogs/dog.783.jpg
#   inflating: /content/dataset/training_set/dogs/dog.784.jpg
#   inflating: /content/dataset/training_set/dogs/dog.785.jpg
#   inflating: /content/dataset/training_set/dogs/dog.786.jpg
#   inflating: /content/dataset/training_set/dogs/dog.787.jpg
#   inflating: /content/dataset/training_set/dogs/dog.788.jpg
#   inflating: /content/dataset/training_set/dogs/dog.789.jpg
#   inflating: /content/dataset/training_set/dogs/dog.79.jpg
#   inflating: /content/dataset/training_set/dogs/dog.790.jpg
#   inflating: /content/dataset/training_set/dogs/dog.791.jpg
#   inflating: /content/dataset/training_set/dogs/dog.792.jpg
#   inflating: /content/dataset/training_set/dogs/dog.793.jpg
#   inflating: /content/dataset/training_set/dogs/dog.794.jpg
#   inflating: /content/dataset/training_set/dogs/dog.795.jpg
#   inflating: /content/dataset/training_set/dogs/dog.796.jpg
#   inflating: /content/dataset/training_set/dogs/dog.797.jpg
#   inflating: /content/dataset/training_set/dogs/dog.798.jpg
#   inflating: /content/dataset/training_set/dogs/dog.799.jpg
#   inflating: /content/dataset/training_set/dogs/dog.8.jpg
#   inflating: /content/dataset/training_set/dogs/dog.80.jpg
#   inflating: /content/dataset/training_set/dogs/dog.800.jpg
#   inflating: /content/dataset/training_set/dogs/dog.801.jpg
#   inflating: /content/dataset/training_set/dogs/dog.802.jpg
#   inflating: /content/dataset/training_set/dogs/dog.803.jpg
#   inflating: /content/dataset/training_set/dogs/dog.804.jpg
#   inflating: /content/dataset/training_set/dogs/dog.805.jpg
#   inflating: /content/dataset/training_set/dogs/dog.806.jpg
#   inflating: /content/dataset/training_set/dogs/dog.807.jpg
#   inflating: /content/dataset/training_set/dogs/dog.808.jpg
#   inflating: /content/dataset/training_set/dogs/dog.809.jpg
#   inflating: /content/dataset/training_set/dogs/dog.81.jpg
#   inflating: /content/dataset/training_set/dogs/dog.810.jpg
#   inflating: /content/dataset/training_set/dogs/dog.811.jpg
#   inflating: /content/dataset/training_set/dogs/dog.812.jpg
#   inflating: /content/dataset/training_set/dogs/dog.813.jpg
#   inflating: /content/dataset/training_set/dogs/dog.814.jpg
#   inflating: /content/dataset/training_set/dogs/dog.815.jpg
#   inflating: /content/dataset/training_set/dogs/dog.816.jpg
#   inflating: /content/dataset/training_set/dogs/dog.817.jpg
#   inflating: /content/dataset/training_set/dogs/dog.818.jpg
#   inflating: /content/dataset/training_set/dogs/dog.819.jpg
#   inflating: /content/dataset/training_set/dogs/dog.82.jpg
#   inflating: /content/dataset/training_set/dogs/dog.820.jpg
#   inflating: /content/dataset/training_set/dogs/dog.821.jpg
#   inflating: /content/dataset/training_set/dogs/dog.822.jpg
#   inflating: /content/dataset/training_set/dogs/dog.823.jpg
#   inflating: /content/dataset/training_set/dogs/dog.824.jpg
#   inflating: /content/dataset/training_set/dogs/dog.825.jpg
#   inflating: /content/dataset/training_set/dogs/dog.826.jpg
#   inflating: /content/dataset/training_set/dogs/dog.827.jpg
#   inflating: /content/dataset/training_set/dogs/dog.828.jpg
#   inflating: /content/dataset/training_set/dogs/dog.829.jpg
#   inflating: /content/dataset/training_set/dogs/dog.83.jpg
#   inflating: /content/dataset/training_set/dogs/dog.830.jpg
#   inflating: /content/dataset/training_set/dogs/dog.831.jpg
#   inflating: /content/dataset/training_set/dogs/dog.832.jpg
#   inflating: /content/dataset/training_set/dogs/dog.833.jpg
#   inflating: /content/dataset/training_set/dogs/dog.834.jpg
#   inflating: /content/dataset/training_set/dogs/dog.835.jpg
#   inflating: /content/dataset/training_set/dogs/dog.836.jpg
#   inflating: /content/dataset/training_set/dogs/dog.837.jpg
#   inflating: /content/dataset/training_set/dogs/dog.838.jpg
#   inflating: /content/dataset/training_set/dogs/dog.839.jpg
#   inflating: /content/dataset/training_set/dogs/dog.84.jpg
#   inflating: /content/dataset/training_set/dogs/dog.840.jpg
#   inflating: /content/dataset/training_set/dogs/dog.841.jpg
#   inflating: /content/dataset/training_set/dogs/dog.842.jpg
#   inflating: /content/dataset/training_set/dogs/dog.843.jpg
#   inflating: /content/dataset/training_set/dogs/dog.844.jpg
#   inflating: /content/dataset/training_set/dogs/dog.845.jpg
#   inflating: /content/dataset/training_set/dogs/dog.846.jpg
#   inflating: /content/dataset/training_set/dogs/dog.847.jpg
#   inflating: /content/dataset/training_set/dogs/dog.848.jpg
#   inflating: /content/dataset/training_set/dogs/dog.849.jpg
#   inflating: /content/dataset/training_set/dogs/dog.85.jpg
#   inflating: /content/dataset/training_set/dogs/dog.850.jpg
#   inflating: /content/dataset/training_set/dogs/dog.851.jpg
#   inflating: /content/dataset/training_set/dogs/dog.852.jpg
#   inflating: /content/dataset/training_set/dogs/dog.853.jpg
#   inflating: /content/dataset/training_set/dogs/dog.854.jpg
#   inflating: /content/dataset/training_set/dogs/dog.855.jpg
#   inflating: /content/dataset/training_set/dogs/dog.856.jpg
#   inflating: /content/dataset/training_set/dogs/dog.857.jpg
#   inflating: /content/dataset/training_set/dogs/dog.858.jpg
#   inflating: /content/dataset/training_set/dogs/dog.859.jpg
#   inflating: /content/dataset/training_set/dogs/dog.86.jpg
#   inflating: /content/dataset/training_set/dogs/dog.860.jpg
#   inflating: /content/dataset/training_set/dogs/dog.861.jpg
#   inflating: /content/dataset/training_set/dogs/dog.862.jpg
#   inflating: /content/dataset/training_set/dogs/dog.863.jpg
#   inflating: /content/dataset/training_set/dogs/dog.864.jpg
#   inflating: /content/dataset/training_set/dogs/dog.865.jpg
#   inflating: /content/dataset/training_set/dogs/dog.866.jpg
#   inflating: /content/dataset/training_set/dogs/dog.867.jpg
#   inflating: /content/dataset/training_set/dogs/dog.868.jpg
#   inflating: /content/dataset/training_set/dogs/dog.869.jpg
#   inflating: /content/dataset/training_set/dogs/dog.87.jpg
#   inflating: /content/dataset/training_set/dogs/dog.870.jpg
#   inflating: /content/dataset/training_set/dogs/dog.871.jpg
#   inflating: /content/dataset/training_set/dogs/dog.872.jpg
#   inflating: /content/dataset/training_set/dogs/dog.873.jpg
#   inflating: /content/dataset/training_set/dogs/dog.874.jpg
#   inflating: /content/dataset/training_set/dogs/dog.875.jpg
#   inflating: /content/dataset/training_set/dogs/dog.876.jpg
#   inflating: /content/dataset/training_set/dogs/dog.877.jpg
#   inflating: /content/dataset/training_set/dogs/dog.878.jpg
#   inflating: /content/dataset/training_set/dogs/dog.879.jpg
#   inflating: /content/dataset/training_set/dogs/dog.88.jpg
#   inflating: /content/dataset/training_set/dogs/dog.880.jpg
#   inflating: /content/dataset/training_set/dogs/dog.881.jpg
#   inflating: /content/dataset/training_set/dogs/dog.882.jpg
#   inflating: /content/dataset/training_set/dogs/dog.883.jpg
#   inflating: /content/dataset/training_set/dogs/dog.884.jpg
#   inflating: /content/dataset/training_set/dogs/dog.885.jpg
#   inflating: /content/dataset/training_set/dogs/dog.886.jpg
#   inflating: /content/dataset/training_set/dogs/dog.887.jpg
#   inflating: /content/dataset/training_set/dogs/dog.888.jpg
#   inflating: /content/dataset/training_set/dogs/dog.889.jpg
#   inflating: /content/dataset/training_set/dogs/dog.89.jpg
#   inflating: /content/dataset/training_set/dogs/dog.890.jpg
#   inflating: /content/dataset/training_set/dogs/dog.891.jpg
#   inflating: /content/dataset/training_set/dogs/dog.892.jpg
#   inflating: /content/dataset/training_set/dogs/dog.893.jpg
#   inflating: /content/dataset/training_set/dogs/dog.894.jpg
#   inflating: /content/dataset/training_set/dogs/dog.895.jpg
#   inflating: /content/dataset/training_set/dogs/dog.896.jpg
#   inflating: /content/dataset/training_set/dogs/dog.897.jpg
#   inflating: /content/dataset/training_set/dogs/dog.898.jpg
#   inflating: /content/dataset/training_set/dogs/dog.899.jpg
#   inflating: /content/dataset/training_set/dogs/dog.9.jpg
#   inflating: /content/dataset/training_set/dogs/dog.90.jpg
#   inflating: /content/dataset/training_set/dogs/dog.900.jpg
#   inflating: /content/dataset/training_set/dogs/dog.901.jpg
#   inflating: /content/dataset/training_set/dogs/dog.902.jpg
#   inflating: /content/dataset/training_set/dogs/dog.903.jpg
#   inflating: /content/dataset/training_set/dogs/dog.904.jpg
#   inflating: /content/dataset/training_set/dogs/dog.905.jpg
#   inflating: /content/dataset/training_set/dogs/dog.906.jpg
#   inflating: /content/dataset/training_set/dogs/dog.907.jpg
#   inflating: /content/dataset/training_set/dogs/dog.908.jpg
#   inflating: /content/dataset/training_set/dogs/dog.909.jpg
#   inflating: /content/dataset/training_set/dogs/dog.91.jpg
#   inflating: /content/dataset/training_set/dogs/dog.910.jpg
#   inflating: /content/dataset/training_set/dogs/dog.911.jpg
#   inflating: /content/dataset/training_set/dogs/dog.912.jpg
#   inflating: /content/dataset/training_set/dogs/dog.913.jpg
#   inflating: /content/dataset/training_set/dogs/dog.914.jpg
#   inflating: /content/dataset/training_set/dogs/dog.915.jpg
#   inflating: /content/dataset/training_set/dogs/dog.916.jpg
#   inflating: /content/dataset/training_set/dogs/dog.917.jpg
#   inflating: /content/dataset/training_set/dogs/dog.918.jpg
#   inflating: /content/dataset/training_set/dogs/dog.919.jpg
#   inflating: /content/dataset/training_set/dogs/dog.92.jpg
#   inflating: /content/dataset/training_set/dogs/dog.920.jpg
#   inflating: /content/dataset/training_set/dogs/dog.921.jpg
#   inflating: /content/dataset/training_set/dogs/dog.922.jpg
#   inflating: /content/dataset/training_set/dogs/dog.923.jpg
#   inflating: /content/dataset/training_set/dogs/dog.924.jpg
#   inflating: /content/dataset/training_set/dogs/dog.925.jpg
#   inflating: /content/dataset/training_set/dogs/dog.926.jpg
#   inflating: /content/dataset/training_set/dogs/dog.927.jpg
#   inflating: /content/dataset/training_set/dogs/dog.928.jpg
#   inflating: /content/dataset/training_set/dogs/dog.929.jpg
#   inflating: /content/dataset/training_set/dogs/dog.93.jpg
#   inflating: /content/dataset/training_set/dogs/dog.930.jpg
#   inflating: /content/dataset/training_set/dogs/dog.931.jpg
#   inflating: /content/dataset/training_set/dogs/dog.932.jpg
#   inflating: /content/dataset/training_set/dogs/dog.933.jpg
#   inflating: /content/dataset/training_set/dogs/dog.934.jpg
#   inflating: /content/dataset/training_set/dogs/dog.935.jpg
#   inflating: /content/dataset/training_set/dogs/dog.936.jpg
#   inflating: /content/dataset/training_set/dogs/dog.937.jpg
#   inflating: /content/dataset/training_set/dogs/dog.938.jpg
#   inflating: /content/dataset/training_set/dogs/dog.939.jpg
#   inflating: /content/dataset/training_set/dogs/dog.94.jpg
#   inflating: /content/dataset/training_set/dogs/dog.940.jpg
#   inflating: /content/dataset/training_set/dogs/dog.941.jpg
#   inflating: /content/dataset/training_set/dogs/dog.942.jpg
#   inflating: /content/dataset/training_set/dogs/dog.943.jpg
#   inflating: /content/dataset/training_set/dogs/dog.944.jpg
#   inflating: /content/dataset/training_set/dogs/dog.945.jpg
#   inflating: /content/dataset/training_set/dogs/dog.946.jpg
#   inflating: /content/dataset/training_set/dogs/dog.947.jpg
#   inflating: /content/dataset/training_set/dogs/dog.948.jpg
#   inflating: /content/dataset/training_set/dogs/dog.949.jpg
#   inflating: /content/dataset/training_set/dogs/dog.95.jpg
#   inflating: /content/dataset/training_set/dogs/dog.950.jpg
#   inflating: /content/dataset/training_set/dogs/dog.951.jpg
#   inflating: /content/dataset/training_set/dogs/dog.952.jpg
#   inflating: /content/dataset/training_set/dogs/dog.953.jpg
#   inflating: /content/dataset/training_set/dogs/dog.954.jpg
#   inflating: /content/dataset/training_set/dogs/dog.955.jpg
#   inflating: /content/dataset/training_set/dogs/dog.956.jpg
#   inflating: /content/dataset/training_set/dogs/dog.957.jpg
#   inflating: /content/dataset/training_set/dogs/dog.958.jpg
#   inflating: /content/dataset/training_set/dogs/dog.959.jpg
#   inflating: /content/dataset/training_set/dogs/dog.96.jpg
#   inflating: /content/dataset/training_set/dogs/dog.960.jpg
#   inflating: /content/dataset/training_set/dogs/dog.961.jpg
#   inflating: /content/dataset/training_set/dogs/dog.962.jpg
#   inflating: /content/dataset/training_set/dogs/dog.963.jpg
#   inflating: /content/dataset/training_set/dogs/dog.964.jpg
#   inflating: /content/dataset/training_set/dogs/dog.965.jpg
#   inflating: /content/dataset/training_set/dogs/dog.966.jpg
#   inflating: /content/dataset/training_set/dogs/dog.967.jpg
#   inflating: /content/dataset/training_set/dogs/dog.968.jpg
#   inflating: /content/dataset/training_set/dogs/dog.969.jpg
#   inflating: /content/dataset/training_set/dogs/dog.97.jpg
#   inflating: /content/dataset/training_set/dogs/dog.970.jpg
#   inflating: /content/dataset/training_set/dogs/dog.971.jpg
#   inflating: /content/dataset/training_set/dogs/dog.972.jpg
#   inflating: /content/dataset/training_set/dogs/dog.973.jpg
#   inflating: /content/dataset/training_set/dogs/dog.974.jpg
#   inflating: /content/dataset/training_set/dogs/dog.975.jpg
#   inflating: /content/dataset/training_set/dogs/dog.976.jpg
#   inflating: /content/dataset/training_set/dogs/dog.977.jpg
#   inflating: /content/dataset/training_set/dogs/dog.978.jpg
#   inflating: /content/dataset/training_set/dogs/dog.979.jpg
#   inflating: /content/dataset/training_set/dogs/dog.98.jpg
#   inflating: /content/dataset/training_set/dogs/dog.980.jpg
#   inflating: /content/dataset/training_set/dogs/dog.981.jpg
#   inflating: /content/dataset/training_set/dogs/dog.982.jpg
#   inflating: /content/dataset/training_set/dogs/dog.983.jpg
#   inflating: /content/dataset/training_set/dogs/dog.984.jpg
#   inflating: /content/dataset/training_set/dogs/dog.985.jpg
#   inflating: /content/dataset/training_set/dogs/dog.986.jpg
#   inflating: /content/dataset/training_set/dogs/dog.987.jpg
#   inflating: /content/dataset/training_set/dogs/dog.988.jpg
#   inflating: /content/dataset/training_set/dogs/dog.989.jpg
#   inflating: /content/dataset/training_set/dogs/dog.99.jpg
#   inflating: /content/dataset/training_set/dogs/dog.990.jpg
#   inflating: /content/dataset/training_set/dogs/dog.991.jpg
#   inflating: /content/dataset/training_set/dogs/dog.992.jpg
#   inflating: /content/dataset/training_set/dogs/dog.993.jpg
#   inflating: /content/dataset/training_set/dogs/dog.994.jpg
#   inflating: /content/dataset/training_set/dogs/dog.995.jpg
#   inflating: /content/dataset/training_set/dogs/dog.996.jpg
#   inflating: /content/dataset/training_set/dogs/dog.997.jpg
#   inflating: /content/dataset/training_set/dogs/dog.998.jpg
#   inflating: /content/dataset/training_set/dogs/dog.999.jpg

# %%
import os
import shutil

TESTDIR = "/content/dataset/test_set"
TRAININGDIR = "/content/dataset/training_set"

cats_dir = os.path.join(TESTDIR, 'cats')
dogs_dir = os.path.join(TESTDIR, 'dogs')

def move_files_to_parent(src_dir, parent_dir):
    for filename in os.listdir(src_dir):
        src_file = os.path.join(src_dir, filename)
        dest_file = os.path.join(parent_dir, filename)
        if os.path.isfile(src_file):
            shutil.move(src_file, dest_file)

move_files_to_parent(cats_dir, TESTDIR)
move_files_to_parent(dogs_dir, TESTDIR)

os.rmdir(cats_dir)
os.rmdir(dogs_dir)

print("Arquivos movidos e pastas removidas com sucesso!")

cats_dir = os.path.join(TRAININGDIR, 'cats')
dogs_dir = os.path.join(TRAININGDIR, 'dogs')

move_files_to_parent(cats_dir, TRAININGDIR)
move_files_to_parent(dogs_dir, TRAININGDIR)

os.rmdir(cats_dir)
os.rmdir(dogs_dir)
# Out:
# Arquivos movidos e pastas removidas com sucesso!

# %%
import numpy as np # scientific computing
import kagglehub
import tensorflow as tf  #  numerical computation using data flow graphs
from tensorflow import keras  # deep learning
from keras_preprocessing.image import ImageDataGenerator, load_img  # generate batches of tensor image data with real-time data augmentation
import pandas as pd # structured data
import matplotlib.pyplot as plt # scientific plotting library
import random  # pseudo-random number generators
import os  # for accessing directory structure

d4rklucif3r_cat_and_dogs_path = kagglehub.dataset_download('d4rklucif3r/cat-and-dogs')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/d4rklucif3r/cat-and-dogs?dataset_version_number=1...
# 100%|██████████| 218M/218M [00:05<00:00, 39.1MB/s]
# Extracting files...

# %% [markdown]
# ## Inicializações

# %%
IMAGE_WIDTH = 128  # largura da imagem
IMAGE_HEIGHT = 128 # altura da imagem
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT) # tamanho da imagem
IMAGE_CHANNELS = 3  # número de canais RGB da imagem
DIR_TRAIN = "/content/dataset/training_set/"  # Diretório contendo dados de treinamento
DIR_TEST = "/content/dataset/test_set/"  # Diretório contendo dados de teste

# %% [markdown]
# ## Pré-Processamento dos Dados de Treino e de Teste
#
# Fonte: https://www.kaggle.com/d4rklucif3r/cat-and-dogs

# %% [markdown]
# ### Treino

# %%
# Read the images from the training directory and generates a pandas structure with the name of each file and the class of the image (cat or dog)
filenames = os.listdir(DIR_TRAIN)
categories = []
for filename in filenames:
    categories.append(filename.split('.')[0]) # category = initial part of the file name

df_train = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df_train.head()
# Out:
#        filename category
# 0  dog.1073.jpg      dog
# 1   cat.752.jpg      cat
# 2  dog.3412.jpg      dog
# 3  cat.3465.jpg      cat
# 4  cat.1910.jpg      cat

# %%
df_train.tail()
# Out:
#           filename category
# 7995  dog.3284.jpg      dog
# 7996    dog.42.jpg      dog
# 7997  cat.2153.jpg      cat
# 7998  dog.2536.jpg      dog
# 7999  dog.2590.jpg      dog

# %%
# number of cats and dogs
df_train['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# #### Exibe uma amostra

# %%
# Randomly chooses a file and displays its image
sample = random.choice(filenames)
image = load_img(DIR_TRAIN+sample)
plt.imshow(image)
plt.title(sample)
# Out:
# Text(0.5, 1.0, 'dog.2743.jpg')

# %%
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# Out:
# JPEG
# RGB
# (319, 240)

# %% [markdown]
# ### Representação de imagens RGB
#
# ![imagem-rgb.png](attachment:imagem-rgb.png)
#
# Em imagens coloridas, o padrão RGB (Red, Green, Blue) representa cada pixel como um vetor de três números para os três canais das cores primárias vermelho, verde e azul. Cada número varia de 0 a 255, representando a intensidade da cor correspondente. O três valores combinados formam a cor do pixel. Por exemplo, a cor violeta pode ser representada como 128, 0, 128, uma mistura de intensidade moderada de vermelho e azul, sem o verde.
#
# Já em imagens em escala de cinza (*grayscale*), cada pixel é representado com um único número (entre 0 e 255), o qual determina o quão preto é o pixel (0 é preto e 255 é branco brilhante).

# %%
# convert image to numpy array
data = np.asarray(image)
# summarize shape
print(data.shape)
# Out:
# (240, 319, 3)

# %% [markdown]
# ### Teste

# %%
# Read the images from the test directory and generates a pandas structure with the name of each file and the class of the image (cat or dog)
filenames = os.listdir(DIR_TEST)
categories = []
for filename in filenames:
    categories.append(filename.split('.')[0]) # category = file name

df_test = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df_test.head()
# Out:
#        filename category
# 0  cat.4697.jpg      cat
# 1  dog.4135.jpg      dog
# 2  cat.4244.jpg      cat
# 3  dog.4641.jpg      dog
# 4  dog.4213.jpg      dog

# %%
df_test.tail()
# Out:
#           filename category
# 1995  cat.4039.jpg      cat
# 1996  cat.4355.jpg      cat
# 1997  dog.4655.jpg      dog
# 1998  cat.4139.jpg      cat
# 1999  cat.4362.jpg      cat

# %%
# number of cats and dogs
df_test['category'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %% [markdown]
# #### Exibe uma amostra
#
# Escolha um arquivo aleatório do conjunto de teste e exiba sua imagem

# %%
# Randomly chooses a file and displays its image
### INICIE O CÓDIGO AQUI ### (4 linhas de código)
sample = random.choice(filenames)
image = load_img(DIR_TEST+sample)
plt.imshow(image)
plt.title(sample)
### TERMINE O CÓDIGO AQUI ###
# Out:
# Text(0.5, 1.0, 'cat.4290.jpg')

# %% [markdown]
# ### Data Augmentation
#
# *Data Augmentation* (aumento de dados) é uma técnica usada para expandir artificialmente o conjunto de dados de treinamento. Ela ajuda a evitar o problema de *overfitting*, que faz com que o modelo de treinamento fique muito ajustado aos dados usados para o treinamento, e não gera um bom desempenho em outros conjuntos de dados.
#
# No caso das imagens de gatos e cachorros, a ideia é alterar os dados de treino com pequenas transformações nas imagens, de forma a reproduzir as variações que ocorrem quando alguém tira uma foto. Por exemplo, centralização, diferentes escalas (gatos/cachorros grandes e pequenos), a imagem está rotacionada etc. Além disso, o dataset contém imagens de tamanhos diferentes, e precisam ser padronizadas para dar entrada na rede neural.
#
# As abordagens para *data augmentation* alteram os dados de treino de forma a mudar a representação vetorial, mas mantendo o mesmo rótulo de classe. Algumas transformações populares são: grayscales, horizontal flips, vertical flips, random crops, color jitters, translations, rotations, shift, brightness, and zoom..
#
# Fazendo algumas dessas transformações nos dados de treino, é possível multiplicar o número de exemplos de treino, de forma a criar um modelo mais robusto.
#
# Tutorial para configurar *data augmentation* de imagens em Keras: https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/

# %% [markdown]
# ### Generador de Treino
#
# Documentação: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
#
# Este exemplo foi adaptado de https://www.kaggle.com/uysimty/keras-cnn-dog-or-cat-classification. <br>

# %%
batch_size = 15
train_datagen = ImageDataGenerator(
    rotation_range = 15,
    rescale = 1./255,
    shear_range = 0.1,
    zoom_range = 0.2,
    horizontal_flip = True,
    width_shift_range = 0.1,
    height_shift_range = 0.1
)

# Takes the dataframe and the path to a directory and generates batches.
# The generated batches contain augmented/normalized data.
train_generator = train_datagen.flow_from_dataframe(
    df_train,
    DIR_TRAIN,
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 8000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Generador de Teste
#
# Um gerador de dados pode também ser usado para especificar o dataset de validação e o dataset de teste. Normalmente, uma instância separada de ImageDataGenerator é criada para que se possa configurar a mesma escala de pixels que aquela usada na instância ImageDataGenerator do dataset de treinamento, mas ela não usará *data augmentation*. Isso ocorre porque *data augmentation* é somente usada como uma técnica para expandir artificialmente o dataset de treinamento, para se melhorar o desempenho de um dataset menor.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_dataframe(
    df_test,
    DIR_TEST,
    x_col = 'filename',
    y_col = 'category',
    target_size = IMAGE_SIZE,
    class_mode = 'categorical',
    batch_size = batch_size
)
# Out:
# Found 2000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Exemplo das Imagens Aumentadas

# %%
df_example = df_train.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    df_example,
    DIR_TRAIN,
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Definição do Modelo
#
# Crie um modelo em Keras com a seguinte configuração:
# - Camada de entrada: no formato dos dados de entrada do problema
# - Camada *Flatten*: camada para achatar o vetor de entrada. No padrão RGB, cada imagem é representada como um vetor de 3 dimensões. Entretanto, cada entrada em uma rede neural é composta por um vetor de apenas uma dimensão. Assim, é necessário "achatar" o vetor da imagam para uma dimensão. Isso é feito pela camada *Flatten*, que cria um vetor de uma dimensão concatenando sequencialmente os valores nos vetores dos três canais da imagem. Desta forma, se o vetor imagem tem o formato (128, 128, 3), por exemplo, o vetor achatado terá dimensão (49.152, 1), o resultado de 128 x 128 x 3.
# - Camada 1: 32 neurônios, função de ativação *ReLu*
# - Camada 2: 64 neurônios, função de ativação *ReLu*
# - Camada 3: 32 neurônios, função de ativação *ReLu*
# - Camada 4 (saída): 2 neurônios, função de ativação *Softmax*. Embora tenha apenas duas classes, o problema deve ser modelado como uma classificação multiclasse ("cat" ou "dog"). Assim, a camada de saída deve ter duas unidades e usar a função Softmax.
#
# Documentação: <br>
# Keras: https://keras.io/ <br>
# Flatten layer: https://keras.io/api/layers/reshaping_layers/flatten/ <br>
# Classe *Model*: https://keras.io/api/models/model/ <br>
# Funções de ativação disponíveis: https://keras.io/api/layers/activations/

# %%
### INICIE O CÓDIGO AQUI ### (7 linhas de código)
inputs = keras.Input(shape=(128,128,3))
x = keras.layers.Flatten()(inputs)
x = keras.layers.Dense(units=32, activation="relu")(x)
x = keras.layers.Dense(units=64, activation="relu")(x)
x = keras.layers.Dense(units=32, activation="relu")(x)
outputs = keras.layers.Dense(units=2, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
### TERMINE O CÓDIGO AQUI ###

# %%
# Prints a summary of the network, showing its architecture and parameters.
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 49152)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │       1,572,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,577,154 (6.02 MB)
#  Trainable params: 1,577,154 (6.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **SAÍDA ESPERADA**: <br>
# Confira a configuração da rede e o total de parâmetros = 1,577,154
#
# ---

# %% [markdown]
# ## Compilação do Modelo
#
# Compile o model usando os seguintes parâmetros:
# - Função de perda: categorical_crossentropy
# - Otimizador: adam
# - Métricas: accuracy
#
# Dica 1: use a função *compile*: https://keras.io/api/models/model_training_apis/ <br>
# Dica 2: relação de funções de perda: https://www.tensorflow.org/api_docs/python/tf/keras/losses <br>
# Dica 3: relação de otimizadores: https://www.tensorflow.org/api_docs/python/tf/keras/optimizers <br>
# Dica 4: relação de métricas: https://keras.io/api/metrics/

# %%
### INICIE O CÓDIGO AQUI ### (1 linha de código)
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
### TERMINE O CÓDIGO AQUI ###

# %% [markdown]
# ## Treinamento do Modelo
#
# Ajusta o modelo aos dados de treinamento.
# Devem ser fornecidos os dados de treinamento e o número de épocas (iterações). Uma época é composta por uma única passagem por todos os exemplos do conjunto de treino.
#
# Efetue o treinamento do modelo usando 3 épocas com os dados aumentados do gerador de treino *train_generator*.
#
# Dica: use a função *fit*: https://keras.io/api/models/model_training_apis/

# %%
### INICIE O CÓDIGO AQUI ### (1 linha de código)
history = model.fit(train_generator, epochs = 3)
### TERMINE O CÓDIGO AQUI ###
print(history.history)  # print per-epoch timeseries of metrics values
# Out:
# Epoch 1/3
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 68s 120ms/step - accuracy: 0.5075 - loss: 1.0146
# Epoch 2/3
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 65s 120ms/step - accuracy: 0.5205 - loss: 0.7281
# Epoch 3/3
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 69s 127ms/step - accuracy: 0.5084 - loss: 0.6921
# {'accuracy': [0.5214999914169312, 0.5105000138282776, 0.5061249732971191], 'loss': [0.8309054970741272, 0.7077831625938416, 0.6915047764778137]}

# %% [markdown]
# **SAÍDA ESPERADA**: <br>
# Na época 3, tem-se o seguinte resultado (aproximado): <br>
# {'loss': [0.8931004405021667, 0.6976273059844971, 0.6935341954231262], 'accuracy': [0.5130000114440918, 0.5195000171661377, 0.5037500262260437]}
#
# ---

# %% [markdown]
# ## Avaliação do Modelo
#
# Avalie o desempenho da rede no conjunto de teste usando o gerador de dados aumentados *test_generator*.
#
# Dica: use a função *evaluate*: https://keras.io/api/models/model_training_apis/

# %%
### INICIE O CÓDIGO AQUI ### (1 linha de código)
loss, acc = model.evaluate(test_generator, steps=len(test_generator))
### TERMINE O CÓDIGO AQUI ###
print("Loss: %.2f" % loss, "\nAccuracy: %.2f" % acc)
# Out:
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.4910 - loss: 0.6924
# Loss: 0.69
# Accuracy: 0.50

# %% [markdown]
# **SAÍDA ESPERADA**: <br>
# Valores aproximados:
#
# Loss: 0.69 <br>
# Accuracy: 0.50
#
# ---

# %% [markdown]
# ## Predição
#
# Apresente a predição do conjunto de teste usando o gerador de dados aumentados *test_generator*.
#
# Documentação: <br>
# Função *predict*: https://keras.io/api/models/model_training_apis/ <br>
# Função *argmax*: https://numpy.org/doc/stable/reference/generated/numpy.argmax.html
#
# Na classificação multiclasse, *model.predict* retorna um vetor de probabilidades para cada classe. A função *argmax* retorna o índice do vetor com a maior probabilidade, neste caso, 0 para gato e 1 para cachorro.

# %%
### INICIE O CÓDIGO AQUI ### (1 linha de código)
predictions = model.predict(test_generator)
### TERMINE O CÓDIGO AQUI ###
preds = [np.argmax(x, axis=-1) for x in predictions]
print("Predictions: ", ["cat" if x == 0 else "dog" for x in preds[:30]]) # print the first 30 predictions
print("\nCorrect:     ", [x for x in df_test['category'][:30]])
# Out:
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step
# Predictions:  ['dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog']
#
# Correct:      ['cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat', 'cat', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'dog', 'cat']

# %% [markdown]
# **SAÍDA ESPERADA**: <br>
# Valores aproximados: <br>
# Predictions:  ['dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog']
#
# Correct:      ['dog', 'cat', 'cat', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'cat', 'dog', 'cat', 'dog', 'dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'cat', 'dog', 'cat', 'cat', 'cat', 'cat', 'cat', 'cat']
#
# ---

# %% [markdown]
# # Fim
#
# Esses foram os passos para criação de uma rede neural simples para classificação de imagens. Lembrando que para se obter uma melhor eficácia, devem ser adicionadas algumas camadas de Redes Neurais Convolucionais (CNN), que é assunto do próximo curso.
#
# -------------------------------------------
